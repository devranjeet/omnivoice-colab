# %% [markdown]
# # 🎙️ **OmniVoice Studio — Google Colab & Drive**
#
# Zero-Shot Voice Cloning, Character Voice Design & Hindi/English Storytelling Studio.
# All data, models, and generated audios are saved in: `/content/drive/MyDrive/OKala_Drive/ominivoice`
#
# ### 🏷️ **Credits & License**
# * 🔗 [OmniVoice GitHub](https://github.com/k2-fsa/OmniVoice) | [Apache 2.0 License](https://github.com/k2-fsa/OmniVoice/blob/master/LICENSE)

# %%
# Step 1: Mount Google Drive
from google.colab import drive
import os

drive.mount('/content/drive')

DRIVE_PATH = "/content/drive/MyDrive/OKala_Drive/ominivoice"
os.makedirs(DRIVE_PATH, exist_ok=True)

print(f"✅ Google Drive Connected! Workspace: {DRIVE_PATH}")

# %%
# Step 2: Install OmniVoice Studio into Google Drive
DRIVE_PATH = "/content/drive/MyDrive/OKala_Drive/ominivoice"
# %cd {DRIVE_PATH}

import os

# Pull latest code safely even if directory is not empty
if not os.path.exists(f"{DRIVE_PATH}/server.py"):
    # !git init
    # !git remote remove origin 2>/dev/null || true
    # !git remote add origin https://github.com/h-ravi/ominivoice_ui.git
    # !git fetch origin main
    # !git reset --hard origin/main
else:
    # !git pull origin main

# Ensure subfolders exist for models, audios, and samples
os.makedirs(f"{DRIVE_PATH}/OmniVoice_Model", exist_ok=True)
os.makedirs(f"{DRIVE_PATH}/Omni_Audio", exist_ok=True)
os.makedirs(f"{DRIVE_PATH}/samples", exist_ok=True)

# Clone OmniVoice core library if missing
if not os.path.exists(f"{DRIVE_PATH}/OmniVoice"):
    # !git clone https://github.com/k2-fsa/OmniVoice.git

# Install dependencies
# !pip install -r colab.txt

from IPython.display import clear_output
clear_output()
print("✅ OmniVoice Studio Installed Successfully in Google Drive!")

# %%
# Step 3: Run OmniVoice Studio (Cloudflare Tunnel)
DRIVE_PATH = "/content/drive/MyDrive/OKala_Drive/ominivoice"
# %cd {DRIVE_PATH}

# !python server.py --tunnel cloudflare
